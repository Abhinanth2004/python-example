# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinanth2004/python-example/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tensor Flow

# %%
import tensorflow as tf
hi=tf.constant("Hello this is Tensor flow")
print(hi.numpy().decode('utf-8'))
# Out:
# Hello this is Tensor flow

# %%
import tensorflow as tf
a=tf.constant(10)
b=tf.constant(20)
#perform on basic operations using tensor framework
add=tf.add(a,b)
sub=tf.subtract(a,b)
mul=tf.multiply(a,b)
div=tf.divide(a,b)
print(f"addition is: {add.numpy()}")
print(f"Subtraction is:{sub.numpy()}")
print(f"Multiplication is:{mul.numpy()}")
print(f"division is:{div.numpy()}")
# Out:
# addition is: 30
# Subtraction is:-10
# Multiplication is:200
# division is:0.5

# %%
import tensorflow as tf
tensor1=tf.constant([[1,2],[3,4]])
tensor2=tf.constant([[5,6],[7,8]])
#matrix multiplication using tensor
result=tf.matmul(tensor1,tensor2)
print(result)
# Out:
# tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)

# %%
import tensorflow as tf
import numpy as np

#generate sample data like(y=2x)
X=np.array([1,2,3,4,5], dtype=np.float32)
Y=np.array([2,4,6,8,10], dtype=np.float32)

#define a simple linear model
model=tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])

#compile the model with optimizer and loss function
model.compile(optimizer='sgd', loss='mean_squared_error')

#train the model
model.fit(X,Y,epochs=500, verbose=0)

#make a prediction
new_input=np.array([6], dtype=np.float32)
prediction=model.predict(new_input)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# [[11.885588]]

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models

# Step 1: Load MNIST dataset
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

# Step 2: Normalize images to values between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0

# Step 3: Build the neural network model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Flatten the input images to 1D (28x28 -> 784)
    layers.Dense(128, activation='relu'),  # Dense layer with 128 neurons and ReLU activation
    layers.Dense(10, activation='softmax') # Output layer with 10 units (one for each digit 0-9)
])

# Step 4: Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Step 5: Train the model
model.fit(train_images, train_labels, epochs=5)

# Step 6: Evaluate the model's performance on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")

# Step 7: Make predictions
predictions = model.predict(test_images)

# Print prediction for the first test image
print(f"Prediction for the first test image: {np.argmax(predictions[0])}")

# Step 8: Visualize the first few test images and their predictions
for i in range(5):
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.title(f"Prediction: {np.argmax(predictions[i])}")
    plt.show()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8770 - loss: 0.4304
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9647 - loss: 0.1196
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9763 - loss: 0.0766
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9836 - loss: 0.0539
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9857 - loss: 0.0449
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9709 - loss: 0.0938
# Test accuracy: 0.9757000207901001
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# ...

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models

# Step 1: Load MNIST dataset
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

# Step 2: Normalize images to values between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0

# Step 3: Build the neural network model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Flatten the input images to 1D (28x28 -> 784)
    layers.Dense(128, activation='relu'),  # Dense layer with 128 neurons and ReLU activation
    layers.Dense(10, activation='softmax') # Output layer with 10 units (one for each digit 0-9)
])

# Step 4: Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Step 5: Train the model
model.fit(train_images, train_labels, epochs=5)

# Step 6: Evaluate the model's performance on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")

# Step 7: Make predictions
predictions = model.predict(test_images)

# Print prediction for the first test image
print(f"Prediction for the first test image: {np.argmax(predictions[0])}")

# Step 8: Visualize the first few test images and their predictions
for i in range(5):
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.title(f"Prediction: {np.argmax(predictions[i])}")
    plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8751 - loss: 0.4375
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9648 - loss: 0.1207
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9766 - loss: 0.0796
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9830 - loss: 0.0568
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9873 - loss: 0.0416
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9730 - loss: 0.0951
# Test accuracy: 0.9771000146865845
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Prediction for the first test image: 7
